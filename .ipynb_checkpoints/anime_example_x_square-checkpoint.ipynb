# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

fig = plt.figure()
ax = plt.axes(xlim=(-10, 10),ylim=(0,100))
x, y = [], []
line, = plt.plot([], [],'ro',markersize=3)


def init():
    line.set_data([], [])
    return line,

def update(frame):
    x = np.linspace(-10,-10+frame)
    y= x**2
    #y = np.sin( np.pi * (x + 0.02 * frame))
    line.set_data(x, y)
    return line,

ani = FuncAnimation(fig, update, frames=20,
                    init_func=init,interval=200)

ax.set_aspect(1./ax.get_data_ratio())
plt.grid()
from IPython.display import HTML
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img0123b34548124787aa0ba778f415b057">
#     <br>
#     <input id="_anim_slider0123b34548124787aa0ba778f415b057" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim0123b34548124787aa0ba778f415b057.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim0123b34548124787aa0ba778f415b057.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim0123b34548124787aa0ba778f415b057.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim0123b34548124787aa0ba778f415b057.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim0123b34548124787aa0ba778f415b057.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim0123b34548124787aa0ba778f415b057.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim0123b34548124787aa0ba778f415b057.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim0123b34548124787aa0ba778f415b057.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim0123b34548124787aa0ba778f415b057.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim0123b34548124787aa0ba778f415b057.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select0123b34548124787aa0ba778f415b057" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img0123b34548124787aa0ba778f415b057";
#     var slider_id = "_anim_slider0123b34548124787aa0ba778f415b057";
#     var loop_select_id = "_anim_loop_select0123b34548124787aa0ba778f415b057";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAAEOFJREFUeJzt3G9olfX/x/HXkYNBUP4Bp2fOkePM\
# Od3G1NW8ETJdx0JsIzX/YHRM7YAFqRXoHSHB8hhkmXrn0JJThAPFtsg/hbNDYcnwawZlxqlmuHV0\
# OSc2zdbm9b3Rr/0w9/v+7Jvb53qfno9beu2c+fqwG8+dy8MJeJ7nCQAAY4a4HgAAwH+DgAEATCJg\
# AACTCBgAwCQCBgAwiYABAEwiYAAAkwgYAMAkAgYAMImAAQBMImAAAJMIGADAJAIGADCJgAEATCJg\
# AACTCBgAwCQCBgAwiYABAEwiYAAAkwgYAMAkAgYAMImAAQBMImAAAJMIGADAJAIGADCJgAEATCJg\
# AACTCBgAwCQCBgAwiYABAEwiYANs+fLlysnJUUlJSd+1ixcvKhKJqLCwUJFIRJ2dnZIkz/P0zDPP\
# KBwOq6ysTCdOnHA1GwB8j4ANsGXLlunQoUM3XIvH46qurlY6nVZ1dbXi8bgk6eDBg0qn00qn00ok\
# Elq1apWLyQBgAgEbYDNmzNDIkSNvuNbY2KhoNCpJikajamho6Lv++OOPKxAIaPr06bp06ZIymcyg\
# bwYACwiYA+fPn1coFJIkhUIhtbe3S5La2to0bty4vsfl5eWpra3NyUYA8Lug6wH4X57n3XQtEAj0\
# +9hEIqFEIiFJOvOvf+me/7n+84QJA7Ru8F2/fl1DhmTf71jZei4pe8/W0dGhCxcuuJ6BPyFgDowe\
# PVqZTEahUEiZTEY5OTmSfn/Fdfbs2b7Htba2Kjc3t9/vEYvFFIvFJEkVgYCO//GFb74ZyOmDKpVK\
# qaqqyvWM2y5bzyVl79kqKipcT0A/su9XJQNqamqUTCYlSclkUrW1tX3X33rrLXmep2PHjmnYsGF9\
# txpvST+v4AAgW/EKbIAtWbJEqVRKFy5cUF5enjZu3Kj169dr4cKFqqurU35+vvbs2SNJmjNnjg4c\
# OKBwOKw777xTu3btuqV/4+cJE7LqlRcA3AoCNsB2797d7/WmpqabrgUCAe3cuXOgJwFAVuAWIgDA\
# JAIGADCJgAEATCJgAACTCBgAwCQCBgAwiYABAEwiYAAAkwgYAMAkAgYAMImAAQBMImAAAJMIGADA\
# JAIGADCJgAEATCJgAACTCBgAwCQCBgAwiYABAEwiYAAAkwgYAMAkAgYAMImAAQBMImAAAJMIGADA\
# JAIGADCJgAEATCJgAACTCBgAwCQCBgAwiYABAEwiYAAAkwgYAMAkAgYAMImAOfTqq69q8uTJKikp\
# 0ZIlS3Tt2jW1tLSosrJShYWFWrRokbq7u13PBABfImCOtLW16fXXX9fx48f15Zdfqre3V/X19Vq3\
# bp3Wrl2rdDqtESNGqK6uzvVUAPAlAuZQT0+PfvnlF/X09Ojq1asKhUI6cuSIFixYIEmKRqNqaGhw\
# vBIA/ImAOTJ27Fg9//zzys/PVygU0rBhwzRt2jQNHz5cwWBQkpSXl6e2tjbHSwHAn4KuB/xTdXZ2\
# qrGxUS0tLRo+fLgeffRRHTx48KbHBQKBfp+fSCSUSCT6vlcqlRrIuU50dXVxLmOy+WzwHwLmyOHD\
# hzV+/HiNGjVKkjRv3jx9+umnunTpknp6ehQMBtXa2qrc3Nx+nx+LxRSLxSRJRUVFqqqqGqzpgyaV\
# SnEuY7L5bPAfbiE6kp+fr2PHjunq1avyPE9NTU2aNGmSZs6cqb1790qSksmkamtrHS8FAH8iYI5U\
# VlZqwYIFmjp1qkpLS3X9+nXFYjFt2bJFW7duVTgcVkdHh1asWOF6KgD4ErcQHdq4caM2btx4w7WC\
# ggI1Nzc7WgQAdvAKDABgEgEDAJhEwAAAJhEwAIBJBAwAYBIBAwCYRMAAACYRMACAS
