# %%
import csv
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
plt.rcParams['font.sans-serif']=['SimHei']

#開檔取得資料
with open('multiTimeline2.csv','r',encoding='utf-8') as csvfile:
    reader=csv.reader(csvfile)
    data=[row for row in  reader]

rbc=[int(row[1]) for row in data]
platelet=[int(row[2]) for row in data]

#設定圖表
fig = plt.figure()
ax = plt.axes()
ax.set_xlim(0, 30)
ax.set_ylim(0, 100)

line, = plt.plot([], [])
line1, =plt.plot([],[], color='r')

#初始函式
def init():
    line.set_data([], [])
    line1.set_data([], [])
    return line,line1

#更新函式
def update(frame):
    x=[i for i in range(frame+1)]
    ydata=rbc[:frame+1]
    y1data=platelet[:frame+1]
    
    line.set_data(x,ydata)
    line1.set_data(x,y1data)
    return line,line1


ani = FuncAnimation(fig, update, frames=len(data),
                    init_func=init)

plt.title('近一個月紅血球和血小板的搜尋熱度(台灣)')
plt.ylabel('搜尋熱度',rotation=0)
plt.xlabel('天數')
plt.legend((line,line1),('紅血球','血小板'))
plt.grid()
plt.show()

# %%
from IPython.display import HTML
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img511c6ad870d14437ac481989b4e7c157">
#     <br>
#     <input id="_anim_slider511c6ad870d14437ac481989b4e7c157" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim511c6ad870d14437ac481989b4e7c157.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim511c6ad870d14437ac481989b4e7c157.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim511c6ad870d14437ac481989b4e7c157.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim511c6ad870d14437ac481989b4e7c157.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim511c6ad870d14437ac481989b4e7c157.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim511c6ad870d14437ac481989b4e7c157.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim511c6ad870d14437ac481989b4e7c157.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim511c6ad870d14437ac481989b4e7c157.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim511c6ad870d14437ac481989b4e7c157.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim511c6ad870d14437ac481989b4e7c157.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select511c6ad870d14437ac481989b4e7c157" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img511c6ad870d14437ac481989b4e7c157";
#     var slider_id = "_anim_slider511c6ad870d14437ac481989b4e7c157";
#     var loop_select_id = "_anim_loop_select511c6ad870d14437ac481989b4e7c157";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAAIABJREFUeJzt3X1cjff/B/BXNyqWUrnJzUhumiFZ\
# 8S2Vcldz+0XWss3XKLHM12ZYs02MLZsxxHeTm01uk9thReGglZIoG7O2iKKmVCrdnHP6/P7o4fpJ\
# mRidc+X1fDzO49G5znVd5/05V+d6netz3ekIIQSIiIhkRlfTBRARET0JBhgREckSA4yIiGSJAUZE\
# RLLEACMiIlligBERkSwxwIiISJYYYEREJEsMMCIikiUGGBERyRIDjIiIZIkBRkREssQAIyIiWWKA\
# ERGRLDHAiIhIlhhgREQkSwwwIiKSJQYYkczVdlN1lUr11Ob/NOZVUFBQ53GLi4vrPG593FCeN63X\
# XgwwGcrOzkZ8fLz0/Pbt27h8+TKOHTuGtWvXYuLEiTh16tQTz//q1avYt2/f0yi1Vu+99x5iYmIe\
# e7oDBw4gLCzsid5z/Pjx2LJlCzw9PaFWq2sdp6ysDAkJCc+0nuDgYHz88cd/O46fnx8OHTpUbZhK\
# pcKFCxfwxRdfYPny5dVeO336NIYMGVJtmJubG5KTk2udf4cOHfDXX38BACorK3H9+nUMHjwYqamp\
# UCqVNcZfsGABPD098eqrr1Z7uLm5oU+fPjXG37dvH+bOnVttmLe3N86ePfu37QaAI0eO4NVXX33k\
# eAAQHh6OkJCQGsMTEhIwevRolJWVPXTa33//Xfp727ZtOHbsGIQQeO+996Q6duzYAQAICQlBeHh4\
# nWqi+qWv6QLo8WVmZmLcuHH46aef0KtXL4wePRoGBgbo3Lkz2rRpg/79+8PExOSJ579v3z6kpKQg\
# OTkZmzdvhoWFBYqKitC4cWPo6+vj8uXLuHDhAqysrAAAq1atwtdff4327dtXm09ZWRmUSiVSUlKk\
# Yfn5+YiIiEBQUBDUajU++ugjKBQKGBgY4O7duzA0NERJSQkWL16MUaNGVZvfoUOH4Ojo+NC6L126\
# hHPnzkFXVxeVlZXo3bs3unXrBgBo1KgROnfujGHDhuGvv/5C69atpdpjYmKQnp6O8vJydOvWDbt2\
# 7YKBgcEjP6dH1VMbQ0NDlJeX/+04RkZGMDQ0BADMmzcPO3fuhFqthqWlJbp06YK+fftWG//ChQtw\
# dnaWnhcUFCA3Nxe9e/d+6PybN2+O06dPw9fXF0OHDoWRkRF++eUX+Pj4oHXr1jh69Kg0/uzZszFi\
# xAgYGxvX2p77vfHGG7h27Rry8vLw+++/47PPPoOtrS309fXRrFmzGtMfPHgQn332mfR5q9Vq/PLL\
# L3BxcQEAlJeXY8iQIfjiiy+qTXft2jWsXbsWUVFR1YaXlpZiypQpePvtt2FkZITMzExcv34dTk5O\
# 1cbbsGEDbt26hU8//RTHjh1D586dERkZifPnz2Pu3LlIS0uDjY0NevfujalTp8LT0xOOjo7o0KFD\
# rZ8paYggWdq9e7eYMWOGEEKIgQMHisuXLz+V+VZWVooePXqIxMREsWjRIvH9998LIYR48803xfnz\
# 54UQQri5uYnMzExpmm+//VYEBQXVmFdaWppwcnKqNuzzzz8Xq1evFuXl5cLGxkacO3dOCCFEfn6+\
# 6NChQ415JCcni169eolevXoJExMT0bVrV+n5vUdJSYkQQoikpCSxbNky0bJlS/HVV1+JqKgo0bdv\
# X+Hs7CxatmwpbG1thbOzs+jTp48oLy8XQgjx559/isuXL4tJkyaJ48ePS5+BtbW1NP+OHTuKsrKy\
# x67n/s/0nm+++Ub6rNRqdbXx8vLyRHh4uBg6dKgICgoSR44cEZMnT5bqqs2IESNEq1athJWVlejV\
# q5eIiIgQGzZsEC1bthSdOnUSnTp1Ei+88IIQQoiioiKRmZkpOnfuLK5evSqOHTsmp
