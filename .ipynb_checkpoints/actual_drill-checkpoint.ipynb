# %%
import csv
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
plt.rcParams['font.sans-serif']=['SimHei']

#開檔取得資料
with open('multiTimeline2.csv','r',encoding='utf-8') as csvfile:
    reader=csv.reader(csvfile)
    data=[row for row in  reader]

rbc=[int(row[1]) for row in data]
platelet=[int(row[2]) for row in data]

#設定圖表
fig, ax = plt.subplots(figsize=(10,5))
xdata, ydata,y1data= [], [], []
ax.set_xlim(0, 30)
ax.set_ylim(0, 100)
line, = plt.plot([], [],animated=True)
line1, =plt.plot([],[], color='r', animated=True)

#初始函式
def init():
    line.set_data([], [])
    line1.set_data([], [])
    return line,

#更新函式
def update(frame):
    x=[i for i in range(frame+1)]
    ydata=rbc[:frame+1]
    y1data=platelet[:frame+1]
    
    line.set_data(x,ydata)
    line1.set_data(x,y1data)
    return line,


ani = FuncAnimation(fig, update, frames=len(data),
                    init_func=init)

plt.title('近一個月紅血球和血小板的搜尋熱度(台灣)')
plt.ylabel('搜尋熱度',rotation=0)
plt.xlabel('天數')
plt.legend((line,line1),('紅血球','血小板'))
plt.grid()
plt.show()

# %%
from IPython.display import HTML
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imga397c4b4cf3e4851af60729e4be51af8">
#     <br>
#     <input id="_anim_slidera397c4b4cf3e4851af60729e4be51af8" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anima397c4b4cf3e4851af60729e4be51af8.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anima397c4b4cf3e4851af60729e4be51af8.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anima397c4b4cf3e4851af60729e4be51af8.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anima397c4b4cf3e4851af60729e4be51af8.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anima397c4b4cf3e4851af60729e4be51af8.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anima397c4b4cf3e4851af60729e4be51af8.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anima397c4b4cf3e4851af60729e4be51af8.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anima397c4b4cf3e4851af60729e4be51af8.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anima397c4b4cf3e4851af60729e4be51af8.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anima397c4b4cf3e4851af60729e4be51af8.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selecta397c4b4cf3e4851af60729e4be51af8" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imga397c4b4cf3e4851af60729e4be51af8";
#     var slider_id = "_anim_slidera397c4b4cf3e4851af60729e4be51af8";
#     var loop_select_id = "_anim_loop_selecta397c4b4cf3e4851af60729e4be51af8";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAAIABJREFUeJzt3XlYlPX+//EXi6CGEOCuKa5kmWmg\
# B3dcyTW3DCtzAdG0jmXmMTWXtKPlckzzlLh8c8sFc0nLDW1SEkXC0NLMct9IERCQbWB+f3g5P0lM\
# b4/OqDwf18V1OZ+573ve98ebuV7z4TOf28FisVgEAAAA4I442rsAAAAA4GFCgAYAAAAMIEADAAAA\
# BhCgAQAAAAMI0AAAAIABBGgAAADAAAI0AAAAYAABGgAAADCAAA0AAAAYQIAGAAAADCBAAwAAAAYQ\
# oAEAAAADCNAAAACAAQRoAAAAwAACNAAAAGAAARoAAAAwgAANAAAAGECABgAAAAwgQAMAAAAGEKAB\
# AAAAAwjQAAAAgAEEaAAAAMAAAjQAAABgAAEaAAAAMIAADQAAABhAgAYAAAAMIEADACRJFovlpjaz\
# 2XzPjn8vjpWcnHzH26alpd3xtgWd+71mi9cAYBsEaKAQu3DhgqKjo62PL1++rCNHjmjHjh2aO3eu\
# +vTpo127dt318U+cOKF169bdi1IL9NZbbykyMtLwfhs2bNDixYvv6jV79eqlpUuXKigoSLm5uQVu\
# k5mZqb17997XeiZPnqzRo0f/7TahoaH65ptv8rWZzWYdPHhQ//73vzVjxox8z+3Zs0dt2rTJ19a8\
# eXPFxcUVePzKlSvrzz//lCTl5eXp9OnTat26tQ4cOKCcnJybth8/fryCgoL0/PPP5/tp3ry56tev\
# f9P269at04gRI/K19ezZUz/++OPfnrckbd26Vc8///xtt5OklStXavbs2Te17927V126dFFmZuYt\
# 9/3tt9+s//7yyy+1Y8cOWSwWvfXWW9Y6VqxYIUmaPXu2Vq5ceUc1AXiwOdu7AAD2c+bMGfXo0UPf\
# fvutnn32WXXp0kUuLi6qXr26ypcvr2bNmsnd3f2uj79u3TrFx8crLi5OS5Yskbe3t1JTU1WsWDE5\
# OzvryJEjOnjwoHx8fCRJs2bN0rRp01SpUqV8x8nMzFROTo7i4+OtbUlJSYqIiNC4ceOUm5ur9957\
# TyaTSS4uLrp69apcXV2Vnp6uSZMmqXPnzvmO98033yggIOCWdR8+fFj79++Xo6Oj8vLyVK9ePdWq\
# VUuSVKRIEVWvXl3t27fXn3/+qXLlyllrj4yM1LFjx5SVlaVatWpp9erVcnFxuW0/3a6egri6uior\
# K+tvtylatKhcXV0lSaNGjdKqVauUm5ursmXLqkaNGmrQoEG+7Q8ePKjGjRtbHycnJ+vSpUuqV6/e\
# LY9fsmRJ7dmzRyEhIWrXrp2KFi2qn3/+WcHBwSpXrpy2b99u3X748OHq2LGj3NzcCjyfG7388ss6\
# deqUEhMT9dtvv+mDDz5QnTp15OzsrMcff/ym/Tdu3KgPPvjA2t+5ubn6+eef1aRJE0lSVlaW2rRp\
# o3//+9/59jt16pTmzp2rzZs352vPyMjQgAED1LdvXxUtWlRnzpzR6dOn1bBhw3zbLViwQBcvXtT7\
# 77+vHTt2qHr16tq0aZN++uknjRgxQkePHpWvr6/q1aungQMHKigoSAEBAapcuXKBfQrg4UCABgox\
# f39/zZ49WwsWLNCsWbNUpEgR/fe//1XNmjX/52NbLBYtWLBACxcu1JYtWzRu3Dj17dtXr776qt59\
# 9109++yzCgwMVJEiRaz7uLi4qH///ho/fny+Y/3+++967bXX8rV99tlnGjVqlB577DE9/fTTWrFi\
# hT7++GMlJyerbt26OnHiRL7t9+/fr379+kmSjh8/ru+++04zZ87Mt83u3btVvHhxXb16VRcuXNBH\
# H32k4cOHy9vbW3379lWRIkV09OhRxcfHq0SJElq2bJmioqLk4uKijh076vnnn9eUK
